# %%
# Comment out each of the cell below, one example is shown in cell below

# %%
# ignore warnings in this notebook
import warnings
warnings.filterwarnings("ignore")

# %%
wine_file = "winequality.csv"

# %%
with open(wine_file,
         mode='r',
         encoding='utf-8') as wine:
    wine_output = wine.read()
    print(type(wine_output))
# Out:
# <class 'str'>

# %%
wine_output[:10]
# Out:
# 'fixed acid'

# %%
wine_list = wine_output.split("\n")
wine_list
# Out:
# ['fixed acidity,volatile acidity,citric acid,residual sugar,chlorides,free sulfur dioxide,total sulfur dioxide,density,pH,sulphates,alcohol,TARGET',
#  '7.4,0.7,0.0,1.9,0.076,11.0,34.0,0.9978,3.51,0.56,9.4,5',
#  '7.8,0.88,0.0,2.6,0.098,25.0,67.0,0.9968,3.2,0.68,9.8,5',
#  '7.8,0.76,0.04,2.3,0.092,15.0,54.0,0.997,3.26,0.65,9.8,5',
#  '11.2,0.28,0.56,1.9,0.075,17.0,60.0,0.998,3.16,0.58,9.8,6',
#  '7.4,0.7,0.0,1.9,0.076,11.0,34.0,0.9978,3.51,0.56,9.4,5',
#  '7.4,0.66,0.0,1.8,0.075,13.0,40.0,0.9978,3.51,0.56,9.4,5',
#  '7.9,0.6,0.06,1.6,0.069,15.0,59.0,0.9964,3.3,0.46,9.4,5',
#  '7.3,0.65,0.0,1.2,0.065,15.0,21.0,0.9946,3.39,0.47,10.0,7',
#  '7.8,0.58,0.02,2.0,0.073,9.0,18.0,0.9968,3.36,0.57,9.5,7',
#  '7.5,0.5,0.36,6.1,0.071,17.0,102.0,0.9978,3.35,0.8,10.5,5',
#  '6.7,0.58,0.08,1.8,0.097,15.0,65.0,0.9959,3.28,0.54,9.2,5',
#  '7.5,0.5,0.36,6.1,0.071,17.0,102.0,0.9978,3.35,0.8,10.5,5',
#  '5.6,0.615,0.0,1.6,0.089,16.0,59.0,0.9943,3.58,0.52,9.9,5',
# ...

# %%
wine_list[0].index('volatile acidity')
# Out:
# 14

# %%
import numpy as np
ar=np.array(wine_list)
ar
# Out:
# array(['fixed acidity,volatile acidity,citric acid,residual sugar,chlorides,free sulfur dioxide,total sulfur dioxide,density,pH,sulphates,alcohol,TARGET',
#        '7.4,0.7,0.0,1.9,0.076,11.0,34.0,0.9978,3.51,0.56,9.4,5',
#        '7.8,0.88,0.0,2.6,0.098,25.0,67.0,0.9968,3.2,0.68,9.8,5', ...,
#        '5.9,0.645,0.12,2.0,0.075,32.0,44.0,0.99547,3.57,0.71,10.2,5',
#        '6.0,0.31,0.47,3.6,0.067,18.0,42.0,0.99549,3.39,0.66,11.0,6', ''],
#       dtype='<U144')

# %%
np.where(ar=='chlorides')
# Out:
# (array([], dtype=int64),)

# %%
wine_comma_sep=[]
for i in wine_list:
    wine_comma_sep.append(i.split(","))

# %%
len(wine_comma_sep), len(wine_comma_sep[1])
# Out:
# (1601, 12)

# %%
type((len(wine_comma_sep), len(wine_comma_sep[1])))
# Out:
# tuple

# %%
# WAF to take file name, 
# create list of list with comma and 
# next line as sep and return shape of list

def shape_of_file(file_name):
    temp_list=[]
    with open(file_name, mode='r', encoding='utf-8') as file:
        f1 = file.read()
        rows = f1.split('\n')
        for row in rows:
            temp_list.append(row.split(","))
    return len(temp_list), len(temp_list[0])

# %%
shape_of_file(wine_file)
# Out:
# (1601, 12)

# %%
# WAC that takes a filename and implement a method that returns DF from that file
# define a class with attributs as filename, which will take input from user
# open the file and load in df

class Filename_and_load():
    def __init__(self, filename):
        self.filename=filename
        
    #print filename
    
    def __repr__(self):
        return f"Name of file is {self.filename}"
    
    def read_and_load()

# %%
#__len
# __getitem

# %%
f1 = Filename_and_load("winequality.csv")

# %%
print(f1)
# Out:
# Name of file is winequality.csv

# %%
f1
# Out:
# Name of file is winequality.csv

# %%
a='test'

# %%
type(a)
# Out:
# str

# %%
type(a).__name__
# Out:
# 'str'

# %%
file_name = 'winequality.csv'
temp_list=[]
with open(file_name, mode='r', encoding='utf-8') as file:
    f1 = file.read()
    rows = f1.split('\n')
    for row in rows:
        temp_list.append(row.split(","))

# %%
temp_list
# Out:
# [['fixed acidity',
#   'volatile acidity',
#   'citric acid',
#   'residual sugar',
#   'chlorides',
#   'free sulfur dioxide',
#   'total sulfur dioxide',
#   'density',
#   'pH',
#   'sulphates',
#   'alcohol',
#   'TARGET'],
#  ['7.4',
#   '0.7',
#   '0.0',
#   '1.9',
#   '0.076',
#   '11.0',
#   '34.0',
#   '0.9978',
#   '3.51',
#   '0.56',
#   '9.4',
#   '5'],
#  ['7.8',
#   '0.88',
#   '0.0',
#   '2.6',
#   '0.098',
#   '25.0',
#   '67.0',
#   '0.9968',
#   '3.2',
#   '0.68',
#   '9.8',
#   '5'],
#  ['7.8',
#   '0.76',
#   '0.04',
#   '2.3',
#   '0.092',
#   '15.0',
#   '54.0',
#   '0.997',
#   '3.26',
#   '0.65',
#   '9.8',
#   '5'],
#  ['11.2',
#   '0.28',
#   '0.56',
#   '1.9',
#   '0.075',
#   '17.0',
#   '60.0',
#   '0.998',
#   '3.16',
#   '0.58',
#   '9.8',
#   '6'],
#  ['7.4',
#   '0.7',
#   '0.0',
#   '1.9',
#   '0.076',
#   '11.0',
#   '34.0',
#   '0.9978',
#   '3.51',
#   '0.56',
#   '9.4',
#   '5'],
#  ['7.4',
#   '0.66',
#   '0.0',
#   '1.8',
#   '0.075',
# ...

# %%
import numpy as np
ar = np.array(temp_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 import numpy as np
# ----> 2 ar = np.array(temp_list)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (1601,) + inhomogeneous part.

# %%
[(i, colour.index('chlorides'))
 for i, colour in enumerate(temp_list)
 if 'chlorides' in colour]
# Out:
# [(0, 4)]

# %%
temp_list[0].index('chlorides')
# Out:
# 4

# %%
for i in temp_list:
    print(i[0])
# Out:
# fixed acidity
# 7.4
# 7.8
# 7.8
# 11.2
# 7.4
# 7.4
# 7.9
# 7.3
# 7.8
# 7.5
# 6.7
# 7.5
# 5.6
# 7.8
# 8.9
# 8.9
# 8.5
# 8.1
# 7.4
# 7.9
# 8.9
# 7.6
# 7.9
# 8.5
# 6.9
# 6.3
# 7.6
# 7.9
# 7.1
# 7.8
# 6.7
# 6.9
# 8.3
# 6.9
# 5.2
# 7.8
# 7.8
# 8.1
# 5.7
# 7.3
# 7.3
# 8.8
# 7.5
# 8.1
# 6.8
# 4.6
# 7.7
# 8.7
# 6.4
# 5.6
# 8.8
# 6.6
# 6.6
# 8.6
# 7.6
# 7.7
# 10.2
# 7.5
# 7.8
# 7.3
# 8.8
# 7.7
# 7.5
# 7.0
# 7.2
# 7.2
# 7.5
# 6.6
# 9.3
# 8.0
# 7.7
# 7.7
# 7.7
# 8.3
# 9.7
# 8.8
# 8.8
# 6.8
# 6.7
# 8.3
# 6.2
# 7.8
# 7.4
# 7.3
# 6.3
# 6.9
# 8.6
# 7.7
# 9.3
# 7.0
# 7.9
# 8.6
# 8.6
# 7.7
# 5.0
# 4.7
# 6.8
# 7.0
# 7.6
# 8.1
# 8.3
# 7.8
# 8.1
# 8.1
# 7.2
# 8.1
# 7.8
# 6.2
# 8.0
# 8.1
# 7.8
# 8.4
# 8.4
# 10.1
# 7.8
# 9.4
# 8.3
# 7.8
# 8.8
# 7.0
# 7.3
# 8.8
# 7.3
# 8.0
# 7.8
# 9.0
# 8.2
# 8.1
# 8.0
# 6.1
# 8.0
# 5.6
# 5.6
# 6.6
# 7.9
# 8.4
# 8.3
# 7.2
# 7.8
# 7.8
# 8.4
# 8.3
# 5.2
# 6.3
# 5.2
# 8.1
# 5.8
# 7.6
# 6.9
# 8.2
# 7.3
# 9.2
# 7.5
# 7.5
# 7.1
# 7.1
# 7.1
# 7.1
# 7.1
# 6.8
# 7.6
# 7.6
# 7.8
# ...

# %%
print(__name__)
# Out:
# __main__

# %%
from file_processing_script1 import File
# Out:
# file_processing_script1

# %%
from file_processing_script1 import File

# %%
from file_processing_script1 import File
